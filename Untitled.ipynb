# %%
import requests
import json
import numpy as np
import pandas as pd
from pandas import json_normalize

# %%
auth_endpoint = "https://auth.emsicloud.com/connect/token" # auth endpoint

client_id = 'kx9kua5b0fenqym4' 
client_secret = 'mm3h4Xua' 
scope = "emsi_open" 

payload = "client_id=" + client_id + "&client_secret=" + client_secret + "&grant_type=client_credentials&scope=" + scope # set credentials and scope
headers = {'content-type': 'application/x-www-form-urlencoded'} # headers for the response
access_token = json.loads((requests.request("POST", auth_endpoint, data=payload, headers=headers)).text)['access_token'] # grabs request's text and loads as JSON, then pulls the access token from that

# %%
def extract_skills_list():
  all_skills_endpoint = "https://emsiservices.com/skills/versions/latest/skills" # List of all skills endpoint
  auth = "Authorization: Bearer " + access_token # Auth string including access token from above
  headers = {'authorization': auth} # headers
  response = requests.request("GET", all_skills_endpoint, headers=headers) # response
  response = response.json()['data'] # the data

  all_skills_df = pd.DataFrame(json_normalize(response)); # Where response is a JSON object drilled down to the level of 'data' key
  return all_skills_df

extract_skills_list()
# Out:
#                          id  \
# 0      KS120P86XDXZJT3B7KVJ
# 1      KS126XS6CQCFGC3NG79X
# 2      ES50D03AC9CFC1A0BC93
# 3      KS1200B62W5ZF38RJ7TD
# 4      KS126XW78QJCF4TRV2X7
# ...                     ...
# 34231  BGSE81B40D49CE4E4B79
# 34232  KS440T963CCSV4W7BWJ5
# 34233  BGSEF80D93DCEB320488
# 34234  ES3E9032BC8D03E83CFA
# 34235  KS442937527R0CF82H0M
#
#                                                  infoUrl  \
# 0      https://skills.emsidata.com/skills/KS120P86XDX...
# 1      https://skills.emsidata.com/skills/KS126XS6CQC...
# 2      https://skills.emsidata.com/skills/ES50D03AC9C...
# 3      https://skills.emsidata.com/skills/KS1200B62W5...
# 4      https://skills.emsidata.com/skills/KS126XW78QJ...
# ...                                                  ...
# 34231  https://skills.emsidata.com/skills/BGSE81B40D4...
# 34232  https://skills.emsidata.com/skills/KS440T963CC...
# 34233  https://skills.emsidata.com/skills/BGSEF80D93D...
# 34234  https://skills.emsidata.com/skills/ES3E9032BC8...
# 34235  https://skills.emsidata.com/skills/KS442937527...
#
#                                                name type.id          type.name
# 0      (American Society For Quality) ASQ Certified     ST3      Certification
# 1                                   .NET Assemblies     ST1  Specialized Skill
# 2                                  .NET Development     ST1  Specialized Skill
# 3                                    .NET Framework     ST1  Specialized Skill
# 4                                  .NET Framework 1     ST1  Specialized Skill
# ...                                             ...     ...                ...
# 34231                                         shRNA     ST1  Specialized Skill
# 34232                                    spatialNET     ST1  Specialized Skill
# 34233                                          tvOS     ST1  Specialized Skill
# 34234                                       watchOS     ST1  Specialized Skill
# 34235                                          z/OS     ST1  Specialized Skill
#
# [34236 rows x 5 columns]

# %%
import pdfplumber
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
with pdfplumber.open(r'Raj Chhabria Resume.pdf') as pdf:
    first_page = pdf.pages[0]
    resume_text = first_page.extract_text()

stop_words = set(stopwords.words('english'))
  
word_tokens = word_tokenize(resume_text)

filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
  
filtered_sentence = []
  
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

# %%
def listToString(s):
   
    
    s1 = " "
   
     
    return (s1.join(s))
       
         
resume_text_wo_stopwords = listToString(filtered_sentence)

# %%
wnl = WordNetLemmatizer()

lemmatized_resume_text = wnl.lemmatize(resume_text_wo_stopwords)

tfidf = TfidfVectorizer()

# %%
job_skills = "Flask Django HTML CSS"

# %%
# Extract skills from a document
def extract_skills_from_document():
  skills_from_doc_endpoint = "https://emsiservices.com/skills/versions/latest/extract"
  text = lemmatized_resume_text
  confidence_interval = '1'
  payload = "{ \"text\": \"... " + text + " ...\", \"confidenceThreshold\": " + confidence_interval + " }"

  headers = {
      'authorization': "Bearer " + access_token,
      'content-type': "application/json"
      }

  response = requests.request("POST", skills_from_doc_endpoint, data=payload.encode('utf-8'), headers=headers)
  print(response)
  #skills_found_in_document_df = pd.DataFrame(json_normalize(response.json()['data'])); # Where response is a JSON object drilled down to the level of 'data' key
                                            
  #return skills_found_in_document_df
  
extract_skills_from_document()
# Out:
# <Response [429]>
